# %%
import os
import sys
import yaml
import json
import argparse
from utils import *
from three_stage_model import *

# %%
main_path = "/work2/07346/ashukla/stampede2/ThreeStageModel/output/voll_6000/solution.so"

# %%
# Read model parameters
with open(r'multi.yaml') as file:
    params = yaml.load(file, Loader=yaml.FullLoader)
    
model_scenarios = return_model_scenarios()
params["path_to_input"] = os.getcwd() + "/data/192_Scenario/"

# %%
base_model = three_stage_model(params, model_scenarios)
base_model.model.update()
sol_path = "/work2/07346/ashukla/stampede2/ThreeStageModel/output/voll_6000/solution.sol"
base_model.model.read(sol_path)
base_model.model.update()
# Out:
# Set parameter TokenServer to value "license02.tacc.utexas.edu"

# %%
# voll 6000

# %%
print(base_model.model.getVarByName('i_oc').Start/1e6,
      base_model.model.getVarByName('i_mitigation').Start/1e6,
      base_model.model.getVarByName('i_voll').Start/1e6,
      base_model.model.getVarByName('i_preparedness').Start/1e6)

# %%
print(base_model.model.getVarByName('i_oc').Start/1e6,
      base_model.model.getVarByName('i_mitigation').Start/1e6,
      base_model.model.getVarByName('i_voll').Start/1e6,
      base_model.model.getVarByName('i_preparedness').Start/1e6)
# Out:
# 0.6037037037037016 54.475000000000016 4.7838445191764265 5.76

# %%
for sub_id in base_model.substations:
    print(sub_id, base_model.model.getVarByName('i_oc').Start)
# Out:
# 98 0.0
# 236 0.0
# 239 0.0
# 241 0.0
# 243 0.0
# 244 0.0
# 247 0.0
# 248 0.0
# 249 0.0
# 250 0.0
# 251 0.0
# 255 0.0
# 256 0.0
# 258 0.0
# 260 0.0
# 261 0.0
# 263 0.0
# 264 0.0
# 265 0.0
# 266 0.0
# 269 0.0
# 270 0.0
# 271 0.0
# 272 0.0
# 273 0.0
# 274 0.0
# 275 0.0
# 276 0.0
# 277 0.0
# 278 0.0
# 279 0.0
# 280 0.0
# 281 0.0
# 282 0.0
# 283 0.0
# 284 0.0
# 285 0.0
# 286 0.0
# 287 0.0
# 288 0.0
# 289 0.0
# 290 0.0
# 291 0.0
# 292 0.0
# 294 0.0
# 295 0.0
# 296 0.0
# 297 0.0
# 298 0.0
# 299 0.0
# 300 0.0
# 301 0.0
# 302 0.0
# 303 0.0
# 308 0.0
# 309 0.0
# 310 0.0
# 311 0.0
# 312 0.0
# 313 0.0
# 314 0.0
# 315 0.0
# 321 0.0
# 323 0.0
# 324 0.0
# 327 0.0
# 328 0.0
# 329 0.0
# 330 0.0
# 331 0.0
# 332 0.0
# 333 0.0
# 334 0.0
# 336 0.0
# 337 0.0
# 338 0.0
# 339 0.0
# 340 0.0
# 341 0.0
# 343 0.0
# 347 0.0
# 349 0.0
# 350 0.0
# 351 0.0
# 353 0.0
# 358 0.0
# 359 0.0
# 361 0.0
# 560 0.0
# 631 0.0
# 681 0.0
# 718 0.0
# 720 0.0
# 722 0.0
# 733 0.0
# 735 0.0
# 736 0.0
# 749 0.0
# 752 0.0
# 756 0.0
# 760 0.0
# 765 0.0
# 772 0.0
# 775 0.0
# 786 0.0
# 788 0.0
# 792 0.0
# 796 0.0
# 802 0.0
# 808 0.0
# 822 0.0
# 823 0.0
# 827 0.0
# 828 0.0
# 840 0.0
# 842 0.0
# 862 0.0
# 866 0.0
# 867 0.0
# 870 0.0
# 881 0.0
# 887 0.0
# 898 0.0
# 900 0.0
# 908 0.0
# 909 0.0
# 910 0.0
# 922 0.0
# 923 0.0
# 924 0.0
# 925 0.0
# 926 0.0
# 927 0.0
# 928 0.0
# 929 0.0
# 930 0.0
# 931 0.0
# 932 0.0
# 933 0.0
# 934 0.0
# 935 0.0
# 936 0.0
# 937 0.0
# 938 0.0
# 939 0.0
# 940 0.0
# 941 0.0
# 942 0.0
# 943 0.0
# 944 0.0
